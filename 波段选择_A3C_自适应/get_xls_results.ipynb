# %% [markdown]
# 本脚本用于HDCNN进行对比实验

# %%
#count results
data_name = "Indian_pines"

# %%
###################################
from evaluate_ss import RET
results =[]
for i in range(5):
#     !python get_prefile_ss.py --data_name "Indian_pines" --pt 0.05 --pv 0.1
#     !python train_evalnet_ss_v2.py --data_name "Indian_pines" 
    # !python A3C_main.py --data_name "Indian_pines" --eval_net_path "./checkpoint/Indian_pines.t7" -- out_put_path "./output/Indian_pines"
#     model = RET(data_name)
#     results.append(model.results)
# import numpy as np
# results = np.array(results)
# avarage = results.mean(axis=0)*100
# std = results.std(axis=0)*100
# avg = ["%.1f±%.1f"%(avarage[i],std[i])for i in range(avarage.shape[0])]
# import xlwt
# import time
# #创建一个Workbook对象，相当于创建了一个Excel文件
# book=xlwt.Workbook(encoding="utf-8",style_compression=0)
# sheet = book.add_sheet(data_name, cell_overwrite_ok=True)
# clo_0 = ["OA","AA","Kappa"]+list(range(16))
# row_o = [data_name]+list(range(5))+["avg"]
# for i in range(len(row_o)):
#     sheet.write(0, i,row_o[i])
# for j in range(len(clo_0)):
#     sheet.write(j+1, 0,clo_0[j])
# for i in range(len(results)):
#     for j in range(len(results[0])):
#         sheet.write(j+1, i+1,results[i][j])
# for j in range(len(results[0])):
#     sheet.write(j+1,6,avg[j])
# book.save(data_name+"_BSRL_"+avg[0]+'.xls')
# Out:
# cuda:0
# ===> Try resume from checkpoint
# ===> Load last checkpoint data
# torch.Size([103, 200, 31, 31]) torch.Size([103, 200, 31, 31])
# => all bands acc: 0.610
# ep  50 / 2000
# W_0 Ep: 50 | Ep_r: -10.86 | loss:3.246 | 0 bands | 6.3s
# ep  100 / 2000
# W_0 Ep: 100 | Ep_r: -4.99 | loss:0.595 | 107 bands | 2.8s
# ep  150 / 2000
# W_0 Ep: 150 | Ep_r: -1.30 | loss:0.602 | 96 bands | 2.8s
# ep  200 / 2000
# W_0 Ep: 200 | Ep_r: 0.79 | loss:0.593 | 15 bands | 2.6s
# ep  250 / 2000
# W_0 Ep: 250 | Ep_r: 1.33 | loss:0.603 | 82 bands | 3.0s
# ep  300 / 2000
# W_0 Ep: 300 | Ep_r: 0.85 | loss:0.583 | 70 bands | 3.1s
# ep  350 / 2000
# W_0 Ep: 350 | Ep_r: 2.23 | loss:0.568 | 13 bands | 3.3s
# ep  400 / 2000
# W_0 Ep: 400 | Ep_r: 3.30 | loss:0.565 | 39 bands | 2.8s
# ep  450 / 2000
# W_0 Ep: 450 | Ep_r: 0.23 | loss:0.601 | 158 bands | 3.0s
# ep  500 / 2000
# W_0 Ep: 500 | Ep_r: -0.50 | loss:0.591 | 47 bands | 2.9s
# ep  550 / 2000
# W_0 Ep: 550 | Ep_r: 0.69 | loss:0.589 | 84 bands | 2.9s
# ep  600 / 2000
# W_0 Ep: 600 | Ep_r: 2.34 | loss:0.600 | 26 bands | 2.9s
# ep  650 / 2000
# W_0 Ep: 650 | Ep_r: 3.46 | loss:0.576 | 41 bands | 2.7s
# ep  700 / 2000
# W_0 Ep: 700 | Ep_r: 4.45 | loss:0.583 | 53 bands | 2.5s
# ep  750 / 2000
# W_0 Ep: 750 | Ep_r: 4.64 | loss:0.576 | 47 bands | 2.5s
# ep  800 / 2000
# W_0 Ep: 800 | Ep_r: 4.79 | loss:0.568 | 55 bands | 2.7s
# ep  850 / 2000
# W_0 Ep: 850 | Ep_r: 4.50 | loss:0.577 | 26 bands | 2.7s
# ep  900 / 2000
# W_0 Ep: 900 | Ep_r: 5.01 | loss:0.572 | 42 bands | 2.5s
# ep  950 / 2000
# W_0 Ep: 950 | Ep_r: 4.07 | loss:0.560 | 69 bands | 2.7s
# ep  1000 / 2000
# W_0 Ep: 1000 | Ep_r: 4.95 | loss:0.619 | 34 bands | 2.6s
# ep  1050 / 2000
# W_0 Ep: 1050 | Ep_r: 5.31 | loss:0.574 | 49 bands | 2.5s
# ep  1100 / 2000
# W_0 Ep: 1100 | Ep_r: 5.84 | loss:0.569 | 10 bands | 2.5s
# ep  1150 / 2000
# W_0 Ep: 1150 | Ep_r: 6.65 | loss:0.540 | 56 bands | 2.5s
# ep  1200 / 2000
# W_0 Ep: 1200 | Ep_r: 6.93 | loss:0.559 | 65 bands | 2.7s
# ep  1250 / 2000
# W_0 Ep: 1250 | Ep_r: 5.24 | loss:0.542 | 55 bands | 2.3s
# ep  1300 / 2000
# W_0 Ep: 1300 | Ep_r: 6.14 | loss:0.552 | 72 bands | 2.3s
# ep  1350 / 2000
# W_0 Ep: 1350 | Ep_r: 3.02 | loss:0.510 | 44 bands | 2.5s
# ep  1400 / 2000
# W_0 Ep: 1400 | Ep_r: 4.58 | loss:0.548 | 67 bands | 2.7s
# ep  1450 / 2000
# W_0 Ep: 1450 | Ep_r: 3.10 | loss:0.537 | 39 bands | 2.5s
# ep  1500 / 2000
# W_0 Ep: 1500 | Ep_r: 5.03 | loss:0.562 | 44 bands | 2.6s
# ep  1550 / 2000
# W_0 Ep: 1550 | Ep_r: 4.50 | loss:0.543 | 36 bands | 2.4s
# ep  1600 / 2000
# W_0 Ep: 1600 | Ep_r: 6.12 | loss:0.536 | 54 bands | 2.6s
# ep  1650 / 2000
# W_0 Ep: 1650 | Ep_r: 7.34 | loss:0.515 | 38 bands | 2.4s
# ep  1700 / 2000
# W_0 Ep: 1700 | Ep_r: 8.16 | loss:0.569 | 21 bands | 2.4s
# ep  1750 / 2000
# W_0 Ep: 1750 | Ep_r: 8.45 | loss:0.540 | 48 bands | 2.4s
# ep  1800 / 2000
# W_0 Ep: 1800 | Ep_r: 8.66 | loss:0.519 | 31 bands | 2.5s
# ep  1850 / 2000
# W_0 Ep: 1850 | Ep_r: 9.40 | loss:0.526 | 40 bands | 2.3s
# ep  1900 / 2000
# W_0 Ep: 1900 | Ep_r: 8.73 | loss:0.510 | 44 bands | 2.3s
# ep  1950 / 2000
# W_0 Ep: 1950 | Ep_r: 9.49 | loss:0.510 | 48 bands | 2.5s
# r_max, 0.5251512317699962
# Done
# time :108
# 2020-03-23 22:50:45.395390: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX AVX2
# 2020-03-23 22:50:45.398387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:65:00.0
# totalMemory: 11.00GiB freeMemory: 8.69GiB
# 2020-03-23 22:50:45.398566: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-03-23 22:50:45.874087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-23 22:50:45.874205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-03-23 22:50:45.874259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-03-23 22:50:45.874467: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 8367 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# WARNING:tensorflow:From A3C_main.py:205: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From A3C_main.py:177: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# cuda:0
# ===> Try resume from checkpoint
# ===> Load last checkpoint data
# torch.Size([103, 200, 31, 31]) torch.Size([103, 200, 31, 31])
# => all bands acc: 0.610
# ep  50 / 2000
# W_0 Ep: 50 | Ep_r: 3.32 | loss:0.598 | 32 bands | 6.7s
# ep  100 / 2000
# W_0 Ep: 100 | Ep_r: 3.41 | loss:0.605 | 126 bands | 2.9s
# ep  150 / 2000
# W_0 Ep: 150 | Ep_r: 2.73 | loss:0.605 | 25 bands | 2.9s
# ep  200 / 2000
# W_0 Ep: 200 | Ep_r: 0.90 | loss:0.611 | 162 bands | 3.0s
# ep  250 / 2000
# W_0 Ep: 250 | Ep_r: 2.24 | loss:0.587 | 66 bands | 3.1s
# ep  300 / 2000
# W_0 Ep: 300 | Ep_r: 3.32 | loss:0.626 | 62 bands | 3.1s
# ep  350 / 2000
# W_0 Ep: 350 | Ep_r: 3.80 | loss:0.613 | 39 bands | 2.9s
# ep  400 / 2000
# W_0 Ep: 400 | Ep_r: 4.10 | loss:0.590 | 44 bands | 3.6s
# ep  450 / 2000
# W_0 Ep: 450 | Ep_r: 3.20 | loss:0.611 | 46 bands | 4.0s
# ep  500 / 2000
# W_0 Ep: 500 | Ep_r: 3.58 | loss:0.597 | 24 bands | 3.2s
# ep  550 / 2000
# W_0 Ep: 550 | Ep_r: 1.24 | loss:3.246 | 0 bands | 2.8s
# ep  600 / 2000
# W_0 Ep: 600 | Ep_r: 2.48 | loss:0.590 | 88 bands | 2.8s
# ep  650 / 2000
# W_0 Ep: 650 | Ep_r: 3.47 | loss:0.580 | 93 bands | 2.9s
# ep  700 / 2000
# W_0 Ep: 700 | Ep_r: 3.19 | loss:0.630 | 11 bands | 2.8s
# ep  750 / 2000
# W_0 Ep: 750 | Ep_r: 4.31 | loss:0.592 | 69 bands | 2.8s
# ep  800 / 2000
# W_0 Ep: 800 | Ep_r: 2.68 | loss:0.594 | 53 bands | 3.0s
# ep  850 / 2000
# W_0 Ep: 850 | Ep_r: 4.14 | loss:0.588 | 65 bands | 2.8s
# ep  900 / 2000
# W_0 Ep: 900 | Ep_r: 5.07 | loss:0.579 | 76 bands | 2.7s
# ep  950 / 2000
# W_0 Ep: 950 | Ep_r: 5.82 | loss:0.600 | 9 bands | 2.7s
# ep  1000 / 2000
# W_0 Ep: 1000 | Ep_r: 6.09 | loss:0.591 | 44 bands | 2.6s
# ep  1050 / 2000
# W_0 Ep: 1050 | Ep_r: 4.34 | loss:0.570 | 68 bands | 2.9s
# ep  1100 / 2000
# W_0 Ep: 1100 | Ep_r: 5.55 | loss:0.550 | 64 bands | 2.7s
# ep  1150 / 2000
# W_0 Ep: 1150 | Ep_r: 5.71 | loss:0.570 | 63 bands | 2.7s
# ep  1200 / 2000
# W_0 Ep: 1200 | Ep_r: 6.32 | loss:0.550 | 36 bands | 2.6s
# ep  1250 / 2000
# W_0 Ep: 1250 | Ep_r: 6.82 | loss:0.530 | 47 bands | 2.4s
# ep  1300 / 2000
# W_0 Ep: 1300 | Ep_r: 7.16 | loss:0.533 | 37 bands | 2.5s
# ep  1350 / 2000
# W_0 Ep: 1350 | Ep_r: 7.52 | loss:0.552 | 53 bands | 2.4s
# ep  1400 / 2000
# W_0 Ep: 1400 | Ep_r: 5.31 | loss:3.246 | 0 bands | 2.4s
# ep  1450 / 2000
# W_0 Ep: 1450 | Ep_r: 6.77 | loss:0.526 | 55 bands | 2.3s
# ep  1500 / 2000
# W_0 Ep: 1500 | Ep_r: 7.37 | loss:0.528 | 26 bands | 2.3s
# ep  1550 / 2000
# W_0 Ep: 1550 | Ep_r: 8.32 | loss:0.519 | 39 bands | 2.3s
# ep  1600 / 2000
# W_0 Ep: 1600 | Ep_r: 8.95 | loss:0.526 | 41 bands | 2.1s
# ep  1650 / 2000
# W_0 Ep: 1650 | Ep_r: 9.42 | loss:0.524 | 31 bands | 2.0s
# ep  1700 / 2000
# W_0 Ep: 1700 | Ep_r: 9.84 | loss:0.499 | 31 bands | 2.1s
# ep  1750 / 2000
# W_0 Ep: 1750 | Ep_r: 8.75 | loss:2.165 | 1 bands | 2.1s
# ep  1800 / 2000
# W_0 Ep: 1800 | Ep_r: 9.46 | loss:0.538 | 30 bands | 2.2s
# ep  1850 / 2000
# W_0 Ep: 1850 | Ep_r: 6.14 | loss:0.507 | 43 bands | 2.4s
# ep  1900 / 2000
# W_0 Ep: 1900 | Ep_r: 8.02 | loss:0.499 | 35 bands | 2.4s
# ep  1950 / 2000
# W_0 Ep: 1950 | Ep_r: 9.85 | loss:0.499 | 24 bands | 2.0s
# r_max, 0.49488226510584354
# Done
# time :110
# 2020-03-23 22:52:41.166847: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX AVX2
# 2020-03-23 22:52:41.169844: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce RTX 2080 Ti major: 7 minor: 5 memoryClockRate(GHz): 1.545
# pciBusID: 0000:65:00.0
# totalMemory: 11.00GiB freeMemory: 8.69GiB
# 2020-03-23 22:52:41.170009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-03-23 22:52:41.653358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-23 22:52:41.653469: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-03-23 22:52:41.653529: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-03-23 22:52:41.653741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 8367 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5)
# WARNING:tensorflow:From A3C_main.py:205: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From A3C_main.py:177: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
